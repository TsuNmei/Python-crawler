# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
import pandas as pd

# %%
mb01_1 = pd.read_html("https://www.mobile01.com/topiclist.php?f=747&p=1")[0]

# %%
mb01_1.to_excel("mb01-1.xlsx")

# %%
def mb(x):
    return ("https://www.mobile01.com/topiclist.php?f=747&p="+ str(x))

# %%
for s in range(1,11):
    (pd.read_html(mb(s))[0]).to_excel("mb01.xlsx")

# %%
for s in range(1,11):
    print(pd.read_html(mb(s))[0])
# Out:
#                                         主題  回覆  \
# 0                               剛創業！！！ » 2  11
# 1             想開雞排店 希望有開過的人能給點意見,加盟或自己開都ok   2
# 2                               創業失敗心得 » 2  12
# 3                               住辦大樓設食品加工廠   3
# 4                        作為一位營運者，該如何回饋投資人？   4
# 5                        想創業開一間和牛中盤批發零售可行嗎   5
# 6                        想請問如何成功經營早餐店？ » 2  19
# 7                                     有關殯葬   4
# 8    【快訊】網購族福音！蝦皮24h 服務正式上線 首波20% 現... » 2  14
# 9                                   咖啡小館創業   4
# 10                                    開油漆店   2
# 11                          有沒有客製化廠商可以合作呢?   4
# 12           科技大樓站附近雞肉飯 會貴或是太單調？ »...23456  58
# 13               直銷安麗那麼好賺?! 還是只是充胖子?! » 23  20
# 14              台南缺少賣仙草冰沙,芋頭冰沙,芋圓地瓜圓這類的店嗎?   1
# 15               沒作過生意,想創業賣水煎包,要去哪邊學呢? » 2  13
# 16                              今年年終，你發多少？   4
# 17                請問多益900多分創業能選擇創什麼? » 234  37
# 18                           請問買賣業要如何作帳？謝謝   7
# ...
